# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv as csv

# %%
salaries= "..\project_1\indeed_csv_vs.csv"
file_one_df = pd.read_csv(salaries)

# %%
highest_city=file_one_df.iloc[0:5,2]
career=file_one_df.iloc[0:6,0]
satisfaction = file_one_df.iloc[0:5,5]
salary=file_one_df.iloc[0:6,1]
reported=file_one_df.iloc[0:6,4]
reported
# Out:
# 0        NaN
# 1    84000.0
# 2     5200.0
# 3      807.0
# 4     4900.0
# 5     4100.0
# Name: salaries reported, dtype: float64

# %%
salary_range=np.arange(50000,160000,20000)
salary_range
color=["green","blue","red","purple","yellow","orange"]


plt.bar(career,salary_range,color=color,align="center",edgecolor="white")
plt.xlabel("Careers")
plt.ylabel("Salaries")
plt.title("Indeed Salaries for Data Professional")
plt.xticks(rotation=90)
plt.savefig("indeedavgsalaries.jpg")

# %%
color=["green","blue","red","purple","yellow"]
plt.bar(career,reported,color=color)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.bar( job_title , sal_avg, color='purple', alpha=0.5, align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
#bls data science growth
years=[2019,2020,2021]
employment=[30810,59680,105980]
plt.figure(figsize=(20,10))
plt.plot(years,employment)

years_handle,= plt.plot(years,employment, marker="o", color="Orange", label="Employment")
plt.legend(loc="upper left")
plt.savefig("employmentgrowth.jpg")
